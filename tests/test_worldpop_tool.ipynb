# %%
import sys
sys.path.append("../")

# %%
from worldpop_apis.demographics import Demographics
demo = Demographics()

# %%
lon = 121.473389
lat = 31.228141
lon, lat = demo._to_wgs84(lon, lat, coord_ref="GCJ-02")

# %%
lon
# Out:
# 121.4688651225452

# %%
lat
# Out:
# 31.23008346246342

# %%
ret = demo._compute_window(lat, lon, 500)

# %%
ret
# Out:
# Window(row_slice=slice(np.int32(852), np.int32(863), None), col_slice=slice(np.int32(1629), np.int32(1641), None))

# %%
mask = demo._circle_mask(ret, lat, lon, 500)

# %%
mask
# Out:
# array([False, False, False, False,  True,  True,  True,  True,  True,
#        False, False, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True, False,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False, False, False,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False, False,  True,  True,  True,  True,  True,  True,
# ...

# %%
lon = 121.473389
lat = 31.228141
demo.population_statistics((lat, lon), 500)
# Out:
# PopulationStats(total_population=20948.40609741211, age_breakdown={'age_0_14': 1569.654767036438, 'age_15_59': 14807.459869384766, 'age_60_64': 1555.839877128601, 'age_65_plus': 3430.6956605911255}, age_composition={'age_0_14': 0.07492955596418133, 'age_15_59': 0.7068537720974402, 'age_60_64': 0.07427008383806365, 'age_65_plus': 0.16376881585348593})

# %%
from tools.demographics import DemographicsTool
tool = DemographicsTool()

# %%
tool.call("getPopulationStats", {"location": {"lng": lon, "lat": lat}})
# Out:
# {'provider': 'worldpop',
#  'origin': {'lat': 31.228141, 'lng': 121.473389},
#  'radius_m': 500.0,
#  'coordinate_reference': 'GCJ-02',
#  'total_population': 20948.40609741211,
#  'age_breakdown': {'age_0_14': 1569.654767036438,
#   'age_15_59': 14807.459869384766,
#   'age_60_64': 1555.839877128601,
#   'age_65_plus': 3430.6956605911255},
#  'age_composition': {'age_0_14': 0.07492955596418133,
#   'age_15_59': 0.7068537720974402,
#   'age_60_64': 0.07427008383806365,
#   'age_65_plus': 0.16376881585348593}}
